# %%
import pandas as pd

# %%
# Reading our data into a data frame
df = pd.read_stata('20660-0001-Data.dta')

# %%
# getting summary of our table
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3141 entries, 0 to 3140
# Columns: 470 entries, ID to McareB03
# dtypes: category(195), float64(97), int16(16), int32(154), object(8)
# memory usage: 16.6+ MB

# %%
# getting statistical summary of our data frame 
df.describe()
# Out:
#                 ID       County          FIPS     Latitude    Longitude  \
# count  3141.000000  3141.000000   3141.000000  3140.000000  3140.000000
# mean   1571.000000   103.716651  30408.396689    38.439218   -92.255988
# std     906.872924   107.999484  15152.777343     5.282579    12.915683
# min       1.000000     1.000000   1001.000000    19.683885  -172.454123
# 25%     786.000000    35.000000  18181.000000    34.713675   -98.217642
# 50%    1571.000000    79.000000  29179.000000    38.369629   -90.376130
# 75%    2356.000000   133.000000  45083.000000    41.791306   -83.436484
# max    3141.000000   840.000000  56045.000000    70.599509   -67.550334
#
#             LandArea    WaterArea      PopCen00     PopBase00         Pop00  \
# count    3140.000000  3140.000000  3.140000e+03  3.141000e+03  3.141000e+03
# mean     1126.572710    81.734003  8.962481e+04  8.959714e+04  8.984192e+04
# std      3622.974231   459.131501  2.925045e+05  2.924516e+05  2.932661e+05
# ...

# %%
# selecting the features that are important to us and creating a new data frame
new_df = df[['County', 'StateName', 'CountyName', 'Division', 'Region', 'CBSA', 'CBSA_Status', 'MetroDiv', 'Latitude',
   'Longitude', 'LandArea', 'WaterArea', 'PopBase00', 'Deaths01', 'MedianAge05', 'PctWhite05', 'PctBlack05', 'UnempRate05',
    'EconType04', 'HouseStrs04', 'LowEduc04', 'LowEmp04', 'Retirement04', 'RuralUrban03', 'ClimateRegion', 'PropTaxPerCap02',
    'LocTaxPerCap02', 'CrimeRate04']]

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3141 entries, 0 to 3140
# Data columns (total 28 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   County           3141 non-null   int16
#  1   StateName        3141 non-null   object
#  2   CountyName       3141 non-null   object
#  3   Division         3141 non-null   category
#  4   Region           3141 non-null   category
#  5   CBSA             3141 non-null   category
#  6   CBSA_Status      3141 non-null   category
#  7   MetroDiv         3141 non-null   category
#  8   Latitude         3140 non-null   float64
#  9   Longitude        3140 non-null   float64
#  10  LandArea         3140 non-null   float64
#  11  WaterArea        3140 non-null   float64
#  12  PopBase00        3141 non-null   int32
#  13  Deaths01         3141 non-null   int32
#  14  MedianAge05      3141 non-null   float64
#  15  PctWhite05       3141 non-null   float64
# ...

# %%
# the target variable has 220 missing values
new_df[new_df['CrimeRate04'].isna()]
# Out:
#       County      StateName                  CountyName           Division  \
# 67        13         Alaska      Aleutians East Borough         9: Pacific
# 68        16         Alaska  Aleutians West Census Area         9: Pacific
# 69        20         Alaska      Anchorage Municipality         9: Pacific
# 70        50         Alaska          Bethel Census Area         9: Pacific
# 71        60         Alaska         Bristol Bay Borough         9: Pacific
# ...      ...            ...                         ...                ...
# 2865      97       Virginia       King and Queen County  5: South Atlantic
# 2923     600       Virginia                Fairfax city  5: South Atlantic
# 2942     750       Virginia                Radford city  5: South Atlantic
# 3012      43  West Virginia              Lincoln County  5: South Atlantic
# 3041     101  West Virginia              Webster County  5: South Atlantic
#
# ...

# %%
# pearson correlation of the numeric variables
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize = (12,6))
sns.heatmap(new_df.corr(numeric_only = True), annot = True)
# Out:
# <Axes: >

# %%
# filling the NAs in the crime rate column using linear regression
from sklearn.linear_model import LinearRegression

# %%
df_dropna = new_df.dropna(subset = ['CrimeRate04', 'PopBase00', 'PctWhite05', 'PctBlack05', 'Deaths01'])

# %%
# Define X and y variables
X = df_dropna[['PopBase00', 'PctWhite05', 'PctBlack05', 'Deaths01']]
y = df_dropna['CrimeRate04']

# %%
# fit the linear regression model
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
# Now, predicting the crime rates for rows with missing values
X_missing = new_df[new_df['CrimeRate04'].isna()][['PopBase00', 'PctWhite05', 'PctBlack05', 'Deaths01']]

predicted_crime_rate = model.predict(X_missing)

# %%
# Fillin the NAs in crime rate with the predicted values
new_df.loc[new_df['CrimeRate04'].isna(), 'CrimerRate'] = predicted_crime_rate
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13500\1518591638.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.loc[new_df['CrimeRate04'].isna(), 'CrimerRate'] = predicted_crime_rate

# %%
new_df[new_df['CrimeRate04'].isna()]
# Out:
#       County      StateName                  CountyName           Division  \
# 67        13         Alaska      Aleutians East Borough         9: Pacific
# 68        16         Alaska  Aleutians West Census Area         9: Pacific
# 69        20         Alaska      Anchorage Municipality         9: Pacific
# 70        50         Alaska          Bethel Census Area         9: Pacific
# 71        60         Alaska         Bristol Bay Borough         9: Pacific
# ...      ...            ...                         ...                ...
# 2865      97       Virginia       King and Queen County  5: South Atlantic
# 2923     600       Virginia                Fairfax city  5: South Atlantic
# 2942     750       Virginia                Radford city  5: South Atlantic
# 3012      43  West Virginia              Lincoln County  5: South Atlantic
# 3041     101  West Virginia              Webster County  5: South Atlantic
#
# ...

# %%
# lets replace the NaNs in the crime rate column with the predicted values
new_df['CrimeRate04'] = new_df['CrimeRate04'].fillna(new_df['CrimerRate'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13500\1173140120.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['CrimeRate04'] = new_df['CrimeRate04'].fillna(new_df['CrimerRate'])

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3141 entries, 0 to 3140
# Data columns (total 29 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   County           3141 non-null   int16
#  1   StateName        3141 non-null   object
#  2   CountyName       3141 non-null   object
#  3   Division         3141 non-null   category
#  4   Region           3141 non-null   category
#  5   CBSA             3141 non-null   category
#  6   CBSA_Status      3141 non-null   category
#  7   MetroDiv         3141 non-null   category
#  8   Latitude         3140 non-null   float64
#  9   Longitude        3140 non-null   float64
#  10  LandArea         3140 non-null   float64
#  11  WaterArea        3140 non-null   float64
#  12  PopBase00        3141 non-null   int32
#  13  Deaths01         3141 non-null   int32
#  14  MedianAge05      3141 non-null   float64
#  15  PctWhite05       3141 non-null   float64
# ...

# %%
# dropping the derived column and dropping all rows with missing values
new_df.drop('CrimerRate', axis = 1, inplace = True)
new_df.dropna(inplace = True)
new_df.info()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13500\2980471524.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.drop('CrimerRate', axis = 1, inplace = True)
# C:\Users\user\AppData\Local\Temp\ipykernel_13500\2980471524.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.dropna(inplace = True)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3127 entries, 0 to 3140
# Data columns (total 28 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   County           3127 non-null   int16
#  1   StateName        3127 non-null   object
# ...

# %%
# Performing data augmentation to increase the size of our dataset and improve the performance and generalization of our model

# Duplicating our dataframe with modifications
duplicated_df = new_df.sample(n = 8560, replace = True)

# %%
# Adding noise to the dataset
import numpy as np

def add_noise(x):
    return x + np.random.normal(0, 0.1, len(x))

augmented_df = new_df.copy()
numerical_features = ['Latitude', 'Longitude', 'LandArea', 'WaterArea', 'PopBase00', 'Deaths01', 'MedianAge05',
                      'PctWhite05', 'PctBlack05', 'UnempRate05', 'PropTaxPerCap02', 'LocTaxPerCap02', 'CrimeRate04']

for feature in numerical_features:
    augmented_df[feature] = add_noise(augmented_df[feature])

# %%
# shuffling rows
shuffled_df = new_df.sample(frac=1).reset_index(drop=True)

# %%
# concatenating the augmented dataframes
final_df = pd.concat([new_df, duplicated_df, augmented_df, shuffled_df], ignore_index = True)

# checking the size of the final dataframe
print('Size of the final DataFrame: ', final_df.shape)
# Out:
# Size of the final DataFrame:  (17941, 28)

# %%
final_df
# Out:
#        County  StateName         CountyName               Division  \
# 0           1    Alabama     Autauga County  6: East South Central
# 1           3    Alabama     Baldwin County  6: East South Central
# 2           5    Alabama     Barbour County  6: East South Central
# 3           7    Alabama        Bibb County  6: East South Central
# 4           9    Alabama      Blount County  6: East South Central
# ...       ...        ...                ...                    ...
# 17936     105    Georgia      Elbert County      5: South Atlantic
# 17937     131  Wisconsin  Washington County  3: East North Central
# 17938     117       Iowa       Lucas County  4: West North Central
# 17939     165   Virginia  Rockingham County      5: South Atlantic
# 17940     123   Colorado        Weld County            8: Mountain
#
#            Region              CBSA                       CBSA_Status  \
# 0        3: South             33860  1: Metropolitan Statistical Area
# ...

# %%
# checking again the correlation between the numeric variables of our final dataset
plt.figure(figsize = (12,6))
sns.heatmap(final_df.corr(numeric_only = True), annot = True)
# Out:
# <Axes: >

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17941 entries, 0 to 17940
# Data columns (total 28 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   County           17941 non-null  int16
#  1   StateName        17941 non-null  object
#  2   CountyName       17941 non-null  object
#  3   Division         17941 non-null  category
#  4   Region           17941 non-null  category
#  5   CBSA             17941 non-null  category
#  6   CBSA_Status      17941 non-null  category
#  7   MetroDiv         17941 non-null  category
#  8   Latitude         17941 non-null  float64
#  9   Longitude        17941 non-null  float64
#  10  LandArea         17941 non-null  float64
#  11  WaterArea        17941 non-null  float64
#  12  PopBase00        17941 non-null  float64
#  13  Deaths01         17941 non-null  float64
#  14  MedianAge05      17941 non-null  float64
#  15  PctWhite05       17941 non-null  float64
# ...

# %%
final_df.to_csv('Cleaned and augmented dataset.csv', index =  False)

# %% [markdown]
# ### Exploring the dataset

# %%
sns.histplot(final_df['CrimeRate04'])
# Out:
# <Axes: xlabel='CrimeRate04', ylabel='Count'>

# %%
sns.set_style('darkgrid')
sns.barplot(x = 'LowEduc04', y = 'CrimeRate04', data = final_df)
# Out:
# <Axes: xlabel='LowEduc04', ylabel='CrimeRate04'>

# %%
sns.scatterplot(x = 'UnempRate05', y = 'CrimeRate04', data = final_df)
# Out:
# <Axes: xlabel='UnempRate05', ylabel='CrimeRate04'>

# %%
plt.figure(figsize = (16,6))
sns.barplot(x = 'EconType04', y = 'CrimeRate04', data = final_df)
# Out:
# <Axes: xlabel='EconType04', ylabel='CrimeRate04'>

# %%
sns.barplot(x = 'Retirement04', y = 'CrimeRate04', data = final_df)
# Out:
# <Axes: xlabel='Retirement04', ylabel='CrimeRate04'>

# %%
plt.figure(figsize = (8,4))
sns.scatterplot(x = 'PctBlack05', y = 'CrimeRate04', data = final_df , hue = 'LowEduc04')
# Out:
# <Axes: xlabel='PctBlack05', ylabel='CrimeRate04'>

# %%
plt.figure(figsize = (8,4))
sns.scatterplot(x = 'PctWhite05', y = 'CrimeRate04', data = final_df, hue = 'LowEduc04')
# Out:
# <Axes: xlabel='PctWhite05', ylabel='CrimeRate04'>

# %%
# Working on our categorical variables
categorical_df = final_df[['Division', 'Region', 'CBSA', 'CBSA_Status', 'MetroDiv', 'EconType04', 'HouseStrs04',
          'LowEduc04', 'LowEmp04', 'Retirement04', 'RuralUrban03', 'ClimateRegion']]

# %%
categorical_df.columns
# Out:
# Index(['Division', 'Region', 'CBSA', 'CBSA_Status', 'MetroDiv', 'EconType04',
#        'HouseStrs04', 'LowEduc04', 'LowEmp04', 'Retirement04', 'RuralUrban03',
#        'ClimateRegion'],
#       dtype='object')

# %%
# getting the unique values in our categorical data to determine relevant data points
for feature in categorical_df.columns:
    unique_values = categorical_df[feature].unique()
    print(f"unique features for '{feature}': {unique_values}\n")
# Out:
# unique features for 'Division': ['6: East South Central', '9: Pacific', '8: Mountain', '7: West South Central', '1: New England', '5: South Atlantic', '3: East North Central', '4: West North Central', '2: Middle Atlantic']
# Categories (9, object): ['1: New England' < '2: Middle Atlantic' < '3: East North Central' < '4: West North Central' ... '6: East South Central' < '7: West South Central' < '8: Mountain' < '9: Pacific']
#
# unique features for 'Region': ['3: South', '4: West', '1: Northeast', '2: Midwest']
# Categories (4, object): ['1: Northeast' < '2: Midwest' < '3: South' < '4: West']
#
# unique features for 'CBSA': [33860, 19300, 21640, 13820, '0: Not in a CBSA', ..., 16940, 16220, 43260, 40540, 21740]
# Length: 938
# Categories (939, object): ['0: Not in a CBSA' < 10020 < 10100 < 10140 ... 49660 < 49700 < 49740 < 49780]
#
# unique features for 'CBSA_Status': ['1: Metropolitan Statistical Area', '2: Micropolitan Statistical Area', '0: Not in a CBSA']
# ...

# %%
# number of unique states
final_df['StateName'].nunique()
# Out:
# 51

# %%
# number of unique counties
final_df['County'].nunique()
# Out:
# 323

# %%
# dropping the categorical features from the general data frame
final_df = final_df.drop(columns = categorical_df.columns)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17941 entries, 0 to 17940
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   County           17941 non-null  int16
#  1   StateName        17941 non-null  object
#  2   CountyName       17941 non-null  object
#  3   Latitude         17941 non-null  float64
#  4   Longitude        17941 non-null  float64
#  5   LandArea         17941 non-null  float64
#  6   WaterArea        17941 non-null  float64
#  7   PopBase00        17941 non-null  float64
#  8   Deaths01         17941 non-null  float64
#  9   MedianAge05      17941 non-null  float64
#  10  PctWhite05       17941 non-null  float64
#  11  PctBlack05       17941 non-null  float64
#  12  UnempRate05      17941 non-null  float64
#  13  PropTaxPerCap02  17941 non-null  float64
#  14  LocTaxPerCap02   17941 non-null  float64
#  15  CrimeRate04      17941 non-null  float64
# ...

# %%
# renaming the column names on the categorical df
cat_col_names = {
    'EconType04':'EconType',
    'HouseStrs04':'HouseStrs', 
    'LowEduc04':'LowEduc', 
    'LowEmp04':'LowEmp', 
    'Retirement04':'Retirement', 
    'RuralUrban03':'RuralUrban'
}

categorical_df.rename(columns = cat_col_names, inplace = True)
categorical_df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13500\3056139715.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical_df.rename(columns = cat_col_names, inplace = True)
#                     Division      Region              CBSA  \
# 0      6: East South Central    3: South             33860
# 1      6: East South Central    3: South             19300
# 2      6: East South Central    3: South             21640
# 3      6: East South Central    3: South             13820
# 4      6: East South Central    3: South             13820
# ...                      ...         ...               ...
# 17936      5: South Atlantic    3: South  0: Not in a CBSA
# 17937  3: East North Central  2: Midwest             33340
# 17938  4: West North Central  2: Midwest  0: Not in a CBSA
# ...

# %%
# renaming columns on the general df
new_col_names = {
    'PopBase00':'PopBase',       
    'Deaths01': 'Deaths',
    'MedianAge05':'MedianAge',
    'PctWhite05':'PctWhite',
    'PctBlack05':'PctBlack',
    'UnempRate05':'UnempRate',
    'PropTaxPerCap02':'PropTaxPerCap',
    'LocTaxPerCap02':'LocTaxPerCap',
    'CrimeRate04':'CrimeRate'
}

final_df.rename(columns = new_col_names, inplace = True)
final_df
# Out:
#        County  StateName         CountyName   Latitude   Longitude  LandArea  \
# 0           1    Alabama     Autauga County  32.523283  -86.577176    595.97
# 1           3    Alabama     Baldwin County  30.592781  -87.748260   1596.35
# 2           5    Alabama     Barbour County  31.856515  -85.331312    884.90
# 3           7    Alabama        Bibb County  33.040054  -87.123243    623.03
# 4           9    Alabama      Blount County  33.978461  -86.554768    645.59
# ...       ...        ...                ...        ...         ...       ...
# 17936     105    Georgia      Elbert County  34.129674  -82.874725    368.76
# 17937     131  Wisconsin  Washington County  43.355608  -88.227813    430.82
# 17938     117       Iowa       Lucas County  41.020540  -93.326534    430.55
# 17939     165   Virginia  Rockingham County  38.466513  -78.844380    851.15
# 17940     123   Colorado        Weld County  40.346681 -104.728213   3992.45
#
# ...

# %%
# converting categorical columns to dummy variables
division = pd.get_dummies(categorical_df['Division'], drop_first = True)

# %%
division
# Out:
#        2: Middle Atlantic  3: East North Central  4: West North Central  \
# 0                       0                      0                      0
# 1                       0                      0                      0
# 2                       0                      0                      0
# 3                       0                      0                      0
# 4                       0                      0                      0
# ...                   ...                    ...                    ...
# 17936                   0                      0                      0
# 17937                   0                      1                      0
# 17938                   0                      0                      1
# 17939                   0                      0                      0
# 17940                   0                      0                      0
#
#        5: South Atlantic  6: East South Central  7: West South Central  \
# ...

# %%
def get_dummies(variable):
    dummies = pd.get_dummies(categorical_df[variable], drop_first = True)
    return dummies

region = get_dummies('Region')
CBSA_Status = get_dummies('CBSA_Status')
Econ_type = get_dummies('EconType')
House_strs = get_dummies('HouseStrs')
low_educ = get_dummies('LowEduc')
low_emp = get_dummies('LowEmp')
retirement = get_dummies('Retirement')
rural_urban = get_dummies('RuralUrban')

# %%
# concatenating the dummy variables to the general data frame
final_df = pd.concat([final_df, division, region, CBSA_Status, Econ_type, House_strs,low_educ, low_emp,
                      retirement,rural_urban], axis = 1)

final_df
# Out:
#        County  StateName         CountyName   Latitude   Longitude  LandArea  \
# 0           1    Alabama     Autauga County  32.523283  -86.577176    595.97
# 1           3    Alabama     Baldwin County  30.592781  -87.748260   1596.35
# 2           5    Alabama     Barbour County  31.856515  -85.331312    884.90
# 3           7    Alabama        Bibb County  33.040054  -87.123243    623.03
# 4           9    Alabama      Blount County  33.978461  -86.554768    645.59
# ...       ...        ...                ...        ...         ...       ...
# 17936     105    Georgia      Elbert County  34.129674  -82.874725    368.76
# 17937     131  Wisconsin  Washington County  43.355608  -88.227813    430.82
# 17938     117       Iowa       Lucas County  41.020540  -93.326534    430.55
# 17939     165   Virginia  Rockingham County  38.466513  -78.844380    851.15
# 17940     123   Colorado        Weld County  40.346681 -104.728213   3992.45
#
# ...

# %%
final_df = final_df.drop(columns = ['County', 'StateName', 'CountyName'])

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17941 entries, 0 to 17940
# Data columns (total 43 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Latitude                                                             17941 non-null  float64
#  1   Longitude                                                            17941 non-null  float64
#  2   LandArea                                                             17941 non-null  float64
#  3   WaterArea                                                            17941 non-null  float64
#  4   PopBase                                                              17941 non-null  float64
#  5   Deaths                                                               17941 non-null  float64
# ...

# %%
# splitting the data into train and test sets
from sklearn.model_selection import train_test_split

# %%
X = final_df.drop('CrimeRate', axis = 1)
y = final_df['CrimeRate']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# training and evaluating linear regression model
from sklearn.linear_model import LinearRegression
LR_model = LinearRegression()

# %%
LR_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# getting model's prediction
LR_prediction = LR_model.predict(X_test)

# %%
# visualizing the model's performance on new data
sns.scatterplot(x = LR_prediction, y = y_test)
plt.title("Linear Regression Model Prediction against y_test" )
plt.xlabel('Prediction')
plt.ylabel('y test')
# Out:
# Text(0, 0.5, 'y test')

# %%
# model evaluation
from sklearn.metrics import mean_absolute_error, mean_squared_error

mae = mean_absolute_error(y_test, LR_prediction)
mse = mean_squared_error(y_test, LR_prediction)
rmse = np.sqrt(mse)

print(f'mean absolute error: {round(mae, 2)}')
print(f'mean squared error: {round(mse, 2)}')
print(f'Root mean squared error: {round(rmse, 2)}')
# Out:
# mean absolute error: 911.78
# mean squared error: 1503261.73
# Root mean squared error: 1226.08

# %%
# lets use random forest regressor 
from sklearn.ensemble import RandomForestRegressor
RFR_model = RandomForestRegressor(n_estimators = 200, random_state = 42)

# %%
RFR_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=200, random_state=42)

# %%
RFR_prediction = RFR_model.predict(X_test)

# %%
sns.scatterplot(x = RFR_prediction, y = y_test)
plt.title("Random Forest Regressor Model Prediction against y_test" )
plt.xlabel('Prediction')
plt.ylabel('y test')
# Out:
# Text(0, 0.5, 'y test')

# %%
mae = mean_absolute_error(y_test, RFR_prediction)
mse = mean_squared_error(y_test, RFR_prediction)
rmse = np.sqrt(mse)

print(f'mean absolute error: {round(mae, 2)}')
print(f'mean squared error: {round(mse, 2)}')
print(f'Root mean squared error: {round(rmse, 2)}')
# Out:
# mean absolute error: 88.74
# mean squared error: 38990.96
# Root mean squared error: 197.46

# %%
# using support vector regression
from sklearn.svm import SVR

svr_model = SVR(C = 100, epsilon = 0.1)

# %%
svr_model.fit(X_train, y_train)
# Out:
# SVR(C=100)

# %%
svr_prediction = svr_model.predict(X_test)

# %%
sns.scatterplot(x = svr_prediction, y = y_test)
plt.title("Support Vector Regression Model Prediction against y_test" )
plt.xlabel('Prediction')
plt.ylabel('y test')
# Out:
# Text(0, 0.5, 'y test')

# %%
mae = mean_absolute_error(y_test, svr_prediction)
mse = mean_squared_error(y_test, svr_prediction)
rmse = np.sqrt(mse)

print(f'mean absolute error: {round(mae, 2)}')
print(f'mean squared error: {round(mse, 2)}')
print(f'Root mean squared error: {round(rmse, 2)}')
# Out:
# mean absolute error: 1064.01
# mean squared error: 2137533.53
# Root mean squared error: 1462.03

# %%
# lets scale our variables, optimize our model parameters and check for a different result still using SVR
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# using grid search to search for the best hyperparameters
from sklearn.model_selection import GridSearchCV

param_grid = {
    'kernel':['rbf'],
    'C':[0.1, 1, 10, 100],
    'gamma':[0.1, 1, 10, 100],
    'epsilon':[0.1, 0.01, 0.001]
}
grid_search = GridSearchCV(SVR(), param_grid, cv = 5,verbose = 4)

# %%
grid_search.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV 1/5] END C=0.1, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.053 total time=  39.7s
# [CV 2/5] END C=0.1, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.030 total time=  32.5s
# [CV 3/5] END C=0.1, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.045 total time=  33.4s
# [CV 4/5] END C=0.1, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.040 total time=  32.7s
# [CV 5/5] END C=0.1, epsilon=0.1, gamma=0.1, kernel=rbf;, score=-0.017 total time=  32.9s
# [CV 1/5] END C=0.1, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.056 total time=  41.1s
# [CV 2/5] END C=0.1, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.034 total time=  41.4s
# [CV 3/5] END C=0.1, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.048 total time=  41.6s
# [CV 4/5] END C=0.1, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.044 total time=  42.3s
# [CV 5/5] END C=0.1, epsilon=0.1, gamma=1, kernel=rbf;, score=-0.021 total time=  41.0s
# ...

# %%
# getting the best parameters
best_params = grid_search.best_params_

print(f'Best parameters: {best_params}')
# Out:
# Best parameters: {'C': 100, 'epsilon': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
# using the best params to create a new SVR model
best_svr = SVR(**best_params)

best_svr.fit(X_train_scaled, y_train)
# Out:
# SVR(C=100, gamma=0.1)

# %%
best_svr_pred = best_svr.predict(X_test_scaled)

# %%
sns.scatterplot(x = best_svr_pred, y = y_test)
plt.title("Tuned SVR Model Prediction against y_test" )
plt.xlabel('Prediction')
plt.ylabel('y test')
# Out:
# Text(0, 0.5, 'y test')

# %%
mae = mean_absolute_error(y_test, best_svr_pred)
mse = mean_squared_error(y_test, best_svr_pred)
rmse = np.sqrt(mse)

print(f'mean absolute error: {round(mae, 2)}')
print(f'mean squared error: {round(mse, 2)}')
print(f'Root mean squared error: {round(rmse, 2)}')
# Out:
# mean absolute error: 784.81
# mean squared error: 1555151.39
# Root mean squared error: 1247.06

# %%
# using deep learning sequential model
from keras.models import Sequential
from keras.layers import Dense

# %%
# defining X and y variables and performing train-test split
X = final_df.drop('CrimeRate', axis = 1).values
y = final_df['CrimeRate'].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# using minmax scaler to scale the independent variables
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (12020, 42)

# %%
# instantiating the model and defining its structure and properties
model = Sequential()

model.add(Dense(42, activation = 'relu'))
model.add(Dense(64, activation = 'relu'))
model.add(Dense(64, activation = 'relu'))
model.add(Dense(42, activation = 'relu'))

model.add(Dense(1))

model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
# introducing early stopping callback to our model to monitor validation loss and stop training when it stops improving
from keras.callbacks import EarlyStopping

# %%
early_stopping = EarlyStopping(monitor = 'val_loss', patience = 5, restore_best_weights = True)

# %%
# training the model
model.fit(x=X_train, y=y_train, epochs=400, batch_size=128, validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/400
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000002D2E1C51C60> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_train_function.<locals>.train_function at 0x000002D2E1C51C60>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000002D2E1C51C60> and will run it as-is.
# ...

# %%
losses = pd.DataFrame(model.history.history)

# %%
# visualizing validation loss
losses.plot()
# Out:
# <Axes: >

# %%
seq_prediction = model.predict(X_test)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000002D2DF36E4D0> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_predict_function.<locals>.predict_function at 0x000002D2DF36E4D0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000002D2DF36E4D0> and will run it as-is.
# ...

# %%
mae = mean_absolute_error(y_test, seq_prediction)
mse = mean_squared_error(y_test, seq_prediction)
rmse = np.sqrt(mse)

print(f'mean absolute error: {round(mae, 2)}')
print(f'mean squared error: {round(mse, 2)}')
print(f'Root mean squared error: {round(rmse, 2)}')
# Out:
# mean absolute error: 709.11
# mean squared error: 912725.29
# Root mean squared error: 955.37

# %% [markdown]
# ### A tabular representation of the models' performances
#
# | Model                    | Mean Absolute Error | Mean Squared Error | Root Mean Squared Error |
# |--------------------------|---------------------|--------------------|-------------------------|
# | Linear Regression        | 911.78              | 1503261.73         | 1226.08                 |
# | Random Forest Regressor  | 88.74               | 38990.96           | 197.46                  |
# | Support Vector Regression| 1064.01             | 2137533.53         | 1462.03                 |
# | SVR after Grid Search    | 784.81              | 1555151.39         | 1247.06                 |
# | Sequential DL Model      | 709.11              | 912725.29          | 955.37                  |
